# %% [markdown]
# <a href="https://colab.research.google.com/github/nikemaul/Betterfox/blob/main/Ejer1_03_10_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive #  escribir y ejecutar código Python directamente en tu navegador
import pandas as pd # para analizar y manipular datos o archivos
import numpy as np # realizar operaciones matemáticas y estadísticas en Python
import matplotlib.pyplot as plt # creación de gráficos en dos dimensiones

# %%
from posixpath import sep # permite gestionar rutas de archivos en diferentes plataformas
dato = pd.read_csv("/content/Ejer 1 Mar 10/Ejemplo 1.csv", sep = ",")
dato.head() # encabezado del archivo
# la funcion de max permite extraer la cantidad maxima de una columna
max(dato["ventas"])
# Out:
# 6817634.87

# %%
# la funcion de min permite extraer la cantidad minima de una columna
min(dato["ventas"])
# calcula el promedio de la columna de ventas con numpy
np.mean(dato["ventas"])
# realiza la multiplicacion de las columnas transacciones y ventas
print(dato["transacciones"]*dato["ventas"])
# realiza un grafíco básico
plt.plot(dato["ventas"])
# Out:
# 0     2.860631e+07
# 1     5.686417e+08
# 2     4.525190e+08
# 3     3.054237e+08
# 4     9.276513e+08
# 5     6.607821e+08
# 6     4.880900e+08
# 7     8.546347e+08
# 8     5.968388e+08
# 9     4.411684e+08
# 10    1.128757e+09
# 11    6.897426e+08
# 12    1.153331e+09
# 13    2.116356e+09
# 14    1.710928e+09
# 15    7.738926e+08
# 16    1.624951e+09
# 17    1.025875e+09
# 18    9.322428e+08
# 19    1.382130e+09
# 20    9.826708e+08
# 21    1.054021e+09
# 22    1.888113e+09
# 23    1.435612e+09
# 24    1.785561e+09
# 25    4.997326e+09
# 26    1.145356e+10
# 27    7.176876e+09
# 28    1.084372e+10
# 29    1.146546e+10
# 30    8.860458e+09
# 31    1.046525e+10
# 32    1.070060e+10
# 33    9.233218e+09
# 34    1.401228e+10
# 35    1.547898e+10
# 36    4.601104e+09
# 37    5.084824e+07
# dtype: float64
